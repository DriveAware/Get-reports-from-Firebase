# %%
class Report:
    def __init__(self, key: str, report_type: str, latitude: str, longitude: str, date: str, time: str, address: str,
                 user_id: str, county: str, postal_code: str, email: str):
        self.key = key
        self.report_type = report_type
        self.latitude = latitude
        self.longitude = longitude
        self.date = date
        self.time = time
        self.address = address
        self.user_id = user_id
        self.county = county
        self.postal_code = postal_code
        self.email = email

    def dump(self):
        return " ".join(["\nID:", self.key,
                         "\nemail:", str(self.email),
                         "\nType:", self.report_type,
                         "\nDate:", self.date, "Time:", self.time,
                         "\nLatitude:", self.latitude, "Longitude:", self.longitude,
                         "\nAddress:", self.address,
                         "\nCounty:", self.county,
                         "\nPostal Code:", self.postal_code,
                         "\nUser ID:", self.user_id])

# %%
import firebase_admin
from firebase_admin import db, credentials, auth
from itertools import groupby
from classes import Report


def main():
    cred = credentials.Certificate("android-location-699e9-firebase-adminsdk-49wyo-aa19913070.json")
    firebase_admin.initialize_app(cred, {'databaseURL': 'https://android-location-699e9-default-rtdb.firebaseio.com/'})
    database = db.reference('Locations')
    data = dict(database.get())
    keys = data.keys()
    reports = []
    na = "NA"
    for key in keys:
        try:
            report_type = data[key]['type']
        except KeyError:
            report_type = na
        try:
            report_latitude = data[key]['latitude']
        except KeyError:
            report_latitude = na
        try:
            report_longitude = data[key]['longitude']
        except KeyError:
            report_longitude = na
        try:
            report_date = data[key]['date']
        except KeyError:
            report_date = na
        try:
            report_time = data[key]['time']
        except KeyError:
            report_time = na
        try:
            report_address = data[key]['address']
        except KeyError:
            report_address = na
        try:
            user_reporting_id = data[key]['userId']
        except KeyError:
            user_reporting_id = na
        try:
            report_county = data[key]['county']
        except KeyError:
            report_county = na
        try:
            report_postal_code = data[key]['postalCode']
        except KeyError:
            report_postal_code = na
        try:
            anonymous = data[key]['anonymous']
            print('======================================================', anonymous)
            if not anonymous:
                email = get_user_info(user_reporting_id)
            else:
                email = 'anonymous'
        except KeyError:
            email = get_user_info(user_reporting_id)

        reports.append(Report(key, report_type, report_latitude, report_longitude, report_date, report_time,
                              report_address, user_reporting_id, report_county, report_postal_code, email))
    print_groups(reports)


def get_user_info(user_id):
    page = auth.list_users()
    while page:
        for user in page.users:
            if user.uid == user_id:
                return user.email
        page = page.get_next_page()


def print_groups(reports):
    print('Total # reports:', len(reports))
    groups = [list(result) for key, result in groupby(
        reports, key=lambda obj: obj.email)]
    line = "-------------------------------"
    print(str(len(groups)) + " group(s)\n")
    for group in groups:
        print(str(len(group)) + " report(s)")
        print(line, end="")
        for report in group:
            print(report.dump())
        print(line)
    print('Total # reports:', len(reports))


if __name__ == "__main__":
    main()
# Out:
# ====================================================== True
# ====================================================== False
# ====================================================== False
# ====================================================== True
# Total # reports: 22
# 7 group(s)
#
# 8 report(s)
# -------------------------------
# ID: -MxkgUquKwmQonzZEmGZ
# email: None
# Type: Street begging
# Date: Mar 9, 2022 Time: 15:59:41
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: NA
# Postal Code: NA
# User ID: NA
#
# ID: -MxkvNjzTEHdTFFBXK-h
# email: None
# Type: Street begging
# Date: Mar 9, 2022 Time: 17:04:45
# Latitude: 41.8806362 Longitude: -87.77758229999999
# Address: Address: 436 S Taylor Ave, Oak Park, IL 60302, USA
# County: NA
# Postal Code: NA
# User ID: NA
#
# ID: -MxkvUajWPrlpzGMyZzI
# email: None
# Type: Street begging
# Date: Mar 9, 2022 Time: 17:05:18
# Latitude: 41.880454 Longitude: -87.7771788
# Address: Address: 52 Madison St, Oak Park, IL 60302, USA
# County: NA
# Postal Code: NA
# User ID: NA
#
# ID: -MxkvbmQLJgZACub2LMr
# email: None
# Type: Street begging
# Date: Mar 9, 2022 Time: 17:05:51
# Latitude: 41.8807143 Longitude: -87.7766023
# Address: Address: 435 S Humphrey Ave, Oak Park, IL 60302, USA
# County: NA
# Postal Code: NA
# User ID: NA
#
# ID: -MxkvyREDcf3srVSn711
# email: None
# Type: Street begging
# Date: Mar 9, 2022 Time: 17:07:24
# Latitude: 41.881388099999995 Longitude: -87.7759765
# Address: Address: 418 S Humphrey Ave, Oak Park, IL 60302, USA
# County: NA
# Postal Code: NA
# User ID: NA
#
# ID: -Mxoe4ncrra172EyDK4y
# email: None
# Type: Street begging
# Date: Mar 10, 2022 Time: 10:27:39
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: NA
#
# ID: -MySbtSSgS4KG9HNzs2W
# email: None
# Type: Prostitution
# Date: Mar 18, 2022 Time: 10:22:21
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: NA
#
# ID: -Myi7YpdQoYDusBQjs64
# email: None
# Type: Street begging
# Date: Mar 21, 2022 Time: 15:19:03
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: NA
# -------------------------------
# 1 report(s)
# -------------------------------
# ID: -Mywt75CdPBYrh1GF_ED
# email: alvarolandaluce@gmail.com
# Type: Street begging
# Date: Mar 24, 2022 Time: 12:05:59
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: NWstCnu47UUBD0HxDJ0KzvQ8jB33
# -------------------------------
# 9 report(s)
# -------------------------------
# ID: -Mz005PIZF_TW2W7FxQz
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 07:19:22
# Latitude: 41.8799401 Longitude: -87.7830173
# Address: Madison/Cuyler, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -Mz00ExNlAwaX96yJW-1
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 07:20:02
# Latitude: 41.8800914 Longitude: -87.7849557
# Address: 408 Madison St # B, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -Mz00NMcAtHw5vX3A6KA
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 07:20:32
# Latitude: 41.8800609 Longitude: -87.78862
# Address: 520 Madison St, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -Mz00u_kcihJYSI95bYO
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 07:22:52
# Latitude: 41.879372599999996 Longitude: -87.80330169999999
# Address: 1121 Madison St, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -Mz02LzFh31O4hKVAXE8
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 07:29:12
# Latitude: 41.864092899999996 Longitude: -87.82332799999999
# Address: 7951 Roosevelt Rd, Forest Park, IL 60130, USA
# County: Cook County
# Postal Code: 60130
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -Mz02NiZNHlclXQj15Ro
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 07:29:22
# Latitude: 41.864379299999996 Longitude: -87.8257843
# Address: 8200 Roosevelt Rd, Forest Park, IL 60130, USA
# County: Cook County
# Postal Code: 60130
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -Mz1q7_tPHHvbas65pVP
# email: a@a.com
# Type: Street begging
# Date: Mar 25, 2022 Time: 15:50:28
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -N-KCIllm96byDlkwjsm
# email: a@a.com
# Type: Suspicious Drug Activity
# Date: Apr 10, 2022 Time: 15:39:50
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
#
# ID: -N-KCKocqXJOkRTRgYue
# email: a@a.com
# Type: Suspicious Drug Activity
# Date: Apr 10, 2022 Time: 15:39:50
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
# -------------------------------
# 1 report(s)
# -------------------------------
# ID: -N-KDz8Ztisl7YY5c2se
# email: anonymous
# Type: Street-based Prostitution
# Date: Apr 10, 2022 Time: 15:47:45
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
# -------------------------------
# 1 report(s)
# -------------------------------
# ID: -N-KFeGLFvVaGMIj6nt_
# email: a@a.com
# Type: Street-based Prostitution
# Date: Apr 10, 2022 Time: 15:55:28
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: 5kmmALMM1yTAj2uwLkoY3kxOwQH2
# -------------------------------
# 1 report(s)
# -------------------------------
# ID: -N-ON129ggULWAhbKJ7W
# email: b@b.com
# Type: Street-based Prostitution
# Date: Apr 11, 2022 Time: 11:06:04
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: cCEhNDeE3NaWOs5xxLjEeajDy5x2
# -------------------------------
# 1 report(s)
# -------------------------------
# ID: -N-ONCG3N-bGnUh7haGQ
# email: anonymous
# Type: Street-based Prostitution
# Date: Apr 11, 2022 Time: 11:06:04
# Latitude: 41.8808027 Longitude: -87.77917719999999
# Address: 426 S Lombard Ave, Oak Park, IL 60302, USA
# County: Cook County
# Postal Code: 60302
# User ID: cCEhNDeE3NaWOs5xxLjEeajDy5x2
# -------------------------------
# Total # reports: 22
